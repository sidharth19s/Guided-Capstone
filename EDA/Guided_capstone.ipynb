# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df= pd.read_csv('1589505302_05152020_updated_ski_data_-_updated_ski_data.csv')
df.head()
# Out:
#                   Name   Region    state  summit_elev  vertical_drop  \
# 0       Alyeska Resort   Alaska   Alaska         3939           2500
# 1  Eaglecrest Ski Area   Alaska   Alaska         2600           1540
# 2     Hilltop Ski Area   Alaska   Alaska         2090            294
# 3     Arizona Snowbowl  Arizona  Arizona        11500           2300
# 4  Sunrise Park Resort  Arizona  Arizona        11100           1800
#
#    base_elev  trams  fastEight  fastSixes  fastQuads  ...  LongestRun_mi  \
# 0        250      1        0.0          0          2  ...            1.0
# 1       1200      0        0.0          0          0  ...            2.0
# 2       1796      0        0.0          0          0  ...            1.0
# 3       9200      0        0.0          1          0  ...            2.0
# 4       9200      0        NaN          0          1  ...            1.2
#
#    SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# ...

# %%
df['fastEight'].fillna(0, inplace=True)

# %%
df[df['AdultWeekday']>90].corr()
# Out:
#                    summit_elev  vertical_drop  base_elev     trams  fastEight  \
# summit_elev           1.000000       0.486917   0.969333  0.252537        NaN
# vertical_drop         0.486917       1.000000   0.260365  0.525285        NaN
# base_elev             0.969333       0.260365   1.000000  0.129050        NaN
# trams                 0.252537       0.525285   0.129050  1.000000        NaN
# fastEight                  NaN            NaN        NaN       NaN        NaN
# fastSixes             0.112588      -0.087214   0.174719  0.354988        NaN
# fastQuads             0.336224       0.471659   0.228930  0.423230        NaN
# quad                 -0.346588       0.052112  -0.399588  0.134873        NaN
# triple                0.190539       0.245867   0.141216  0.505068        NaN
# double                0.172061       0.432314   0.067583  0.137641        NaN
# surface               0.281688       0.281895   0.229018  0.311673        NaN
# ...

# %%
plt.plot(df['Runs'],df['AdultWeekday'],'o')

# %%
df[df['Name'].str.contains('Big Mountain')]
# Out:
# 151    105.0
# Name: Runs, dtype: float64

# %%
df[df['AdultWeekday']>85]['Runs'].mean()
# Out:
# 110.72413793103448

# %%
plt.plot(df['vertical_drop'],df['AdultWeekday'],'o')

# %%
df[df['AdultWeekday']>85]['vertical_drop'].mean()
# Out:
# 2574.103448275862

# %%
df.iloc[151]['vertical_drop']
# Out:
# 2353

# %%
plt.plot(df['summit_elev'],df['AdultWeekday'],'o')

# %%
df[df['AdultWeekday']>85]['summit_elev'].mean()
# Out:
# 8541.241379310344

# %%
df.iloc[151]['summit_elev']
# Out:
# 6817

# %%
plt.plot(df['fastQuads'],df['AdultWeekday'],'o')

# %%
df[df['AdultWeekday']>85]['fastQuads'].mean()
# Out:
# 3.7241379310344827

# %%
df.iloc[151]['fastQuads']
# Out:
# 3

# %%
plt.plot(df['total_chairs'],df['AdultWeekday'],'o')

# %%
df[df['AdultWeekday']>85]['total_chairs'].mean()
# Out:
# 13.344827586206897

# %%
df.iloc[151]['total_chairs']
# Out:
# 14

# %%
df[(df['total_chairs']>14) & (df['SkiableTerrain_ac']>3000)]['AdultWeekday']
# Out:
# 11       NaN
# 14     149.0
# 18       NaN
# 27     179.0
# 35       NaN
# 45       NaN
# 46       NaN
# 140      NaN
# 266      NaN
# Name: AdultWeekday, dtype: float64

# %%
df.iloc[[224,241,242,124]].T
# Out:
#                           224                   241  \
# Name               Brandywine  Blue Mountain Resort
# Region                   Ohio          Pennsylvania
# state                    Ohio          Pennsylvania
# summit_elev               871                  1600
# vertical_drop             240                  1082
# base_elev                 631                   460
# trams                       0                     0
# fastEight                   0                     0
# fastSixes                   0                     1
# fastQuads                   0                     1
# quad                        2                     1
# triple                      7                     1
# double                      2                     3
# surface                     5                     9
# total_chairs               16                    16
# Runs                       11                    39
# TerrainParks                2                     5
# ...

# %%
plt.plot(df['Snow Making_ac'],df['AdultWeekday'],'o')

# %%
df[df['AdultWeekday']>85]['Snow Making_ac'].mean()
# Out:
# 358.16

# %%
df.iloc[151]['Snow Making_ac']
# Out:
# 600.0

# %%
import statsmodels.formula.api as smf
results= smf.ols('AdultWeekday ~ total_chairs + Runs + vertical_drop+ summit_elev+ fastQuads', data=df).fit()
results.params
# Out:
# Intercept        26.039476
# total_chairs      1.281411
# Runs              0.082939
# vertical_drop     0.011299
# summit_elev       0.000688
# fastQuads         3.813850
# dtype: float64

# %%
df2 = pd.DataFrame()
df2['Runs']= np.linspace(3,341)
df2['vertical_drop']= np.linspace(60,4425)
df2['summit_elev']= np.linspace(315,13487)
df2['fastQuads']= np.linspace(0,15)
df2['total_chairs']= 14
p12= results.predict(df2)

# %%
p12
# Out:
# 0      45.122881
# 1      48.054130
# 2      50.985380
# 3      53.916629
# 4      56.847878
# 5      59.779127
# 6      62.710376
# 7      65.641626
# 8      68.572875
# 9      71.504124
# 10     74.435373
# 11     77.366622
# 12     80.297872
# 13     83.229121
# 14     86.160370
# 15     89.091619
# 16     92.022868
# 17     94.954118
# 18     97.885367
# 19    100.816616
# 20    103.747865
# 21    106.679114
# 22    109.610364
# 23    112.541613
# 24    115.472862
# 25    118.404111
# 26    121.335360
# 27    124.266610
# 28    127.197859
# 29    130.129108
# 30    133.060357
# 31    135.991606
# 32    138.922856
# 33    141.854105
# 34    144.785354
# 35    147.716603
# 36    150.647852
# 37    153.579102
# 38    156.510351
# 39    159.441600
# 40    162.372849
# 41    165.304098
# 42    168.235348
# 43    171.166597
# 44    174.097846
# 45    177.029095
# 46    179.960344
# 47    182.891594
# 48    185.822843
# 49    188.754092
# dtype: float64

# %% [markdown]
# Using ordinary least squares, it can be seen that ticket prices for resorts with total chair lifts >=14 is > $86. This increment in current prices will be enough to offset additional operational cost.

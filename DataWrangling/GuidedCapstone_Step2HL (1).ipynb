# %% [markdown]
# # Guided Capstone Step 2 Data Wrangling
#
#
# Data wrangling is the second step in the Data Science Method. This step consists of multiple components including Data Collection, Data Organization, Data Definitions, and Data Cleaning.

# %% [markdown]
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   **Data Wrangling**
#   * Data Collection
#       - Locating the data
#       - Data loading
#       - Data joining
#    * Data Organization
#       -  File structure
#       -  Git & Github
#   * Data Definition
#       - Column names
#       - Data types (numeric, categorical, timestamp, etc.)
#       - Description of the columns
#       - Count or percent per unique values or codes (including NA)
#       - The range of values or codes
#   * Data Cleaning
#       - NA or missing data
#       - Duplicates
#
# 3.   Exploratory Data Analysis
#
# 4.   Pre-processing and Training Data Development
#
# 5.   Modeling
#
# 6.   Documentation

# %% [markdown]
# ## Data Collection

# %% [markdown]
# First, you'll load the needed packages and modules into Python. Then you'll load the data into a pandas dataframe for ease of use. Run the cell below to get started.

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Now you need to prepare to load the csv file of your data. You may need to change your path to the location where you saved the csv file on your local machine or you need to save both the csv and the notebook to your working project directory.
# Start by printing the current directory. Hint: you can do this by running the command `os.getcwd()`.

# %% [markdown]
# **<font color='teal'> Print the current working directory </font>**

# %%
os.getcwd()
# Out:
# 'C:\\data_science'

# %% [markdown]
# **<font color='teal'> Print the files in your current directory to make sure the 'updated_ski_data.csv' is present. </font>**
#
#
# Hint: if you're not sure on how to do this, this [link](https://www.geeksforgeeks.org/python-os-listdir-method/) can offer guidance.

# %%
os.listdir('C:\\data_science')
# Out:
# ['.ipynb_checkpoints',
#  '01_first_notebook.ipynb',
#  '01_pandas_intro.ipynb',
#  '02_data_exploration.ipynb',
#  '1.Lab - Data structures in Python - Question.ipynb',
#  '1589505302_05152020_updated_ski_data_-_updated_ski_data.csv',
#  '2.Lab - Numpy-1.ipynb',
#  '3.Lab - Pandas-1.ipynb',
#  'applestore.csv',
#  'assignment3.png',
#  'Assignment3.py',
#  'assignment_3.png',
#  'Assignment_3.py',
#  'Assignment__3.py',
#  'bootcamp',
#  'cab.xlsx',
#  'cab_company.csv',
#  'cars1.csv',
#  'cars_df.png',
#  'Class10.xlsx',
#  'cos plot.png',
#  'Dcsv.csv',
#  'Dcsv1.csv',
#  'DS_Store',
#  'file.xlsx',
#  'file1.ipynb',
#  'file2.ipynb',
#  'GitHub',
#  'googleplaystore.csv',
#  'GuidedCapstone_Step2HL (1).ipynb',
#  'image11.png',
#  'Insurance.csv',
#  'kaggle_clean.csv',
#  'kaggle_clean1.csv',
#  'Manoj.csv',
#  'mtcars.csv',
#  'multiple_choice_responses.csv',
#  'myarray.txt',
#  'New Microsoft Word Document.csv.docx',
#  'New Text Document.csv.txt',
#  'Numpy_and_its_functions.ipynb',
#  'output_companies1.csv',
#  'output_companies2.csv',
#  'output_companies3.txt',
#  'Pandas - Basics.ipynb',
#  'pandas-Consumer.xlsx',
#  'pandas-train.csv',
#  'PART 1, Tier 1 - Sourcing and Loading.ipynb',
#  'PART 2, Tier 1 - Cleaning, transforming and visualizing.ipynb',
#  'PART 3, Tier 1 - Modeling .ipynb',
#  'PART 3, Tier 2 - Modeling.ipynb',
#  'PART 3, Tier 3 - Modelling.ipynb',
#  'PART1, Tier 2 - Sourcing and Loading.ipynb',
#  'PART1, Tier 3 - Sourcing and Loading.ipynb',
#  'PART2, Tier 2 - Cleaning, transforming and visualizing .ipynb',
#  'SagarikaGhosal_Assignment3.ipynb',
#  'SagarikaGhosal_assignment3.png',
#  'SagarikaGhosal_Assignment3.py',
#  'saved_archive.npz',
#  'saved_array.npy',
#  'Tableau',
#  'takenmind.ipynb',
#  'takenmind.py',
#  'titanic.csv',
#  'TMInternship.ipynb',
#  'TMInternship.py',
#  'Unit 4 Challenge - Tier 3.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled14.ipynb',
#  'Untitled15.ipynb',
#  'Untitled16.ipynb',
#  'Untitled17.ipynb',
#  'Untitled18.ipynb',
#  'Untitled19.ipynb',
#  'Untitled2.ipynb',
#  'Untitled20.ipynb',
#  'Untitled21.ipynb',
#  'Untitled22.ipynb',
#  'Untitled23.ipynb',
#  'Untitled24.ipynb',
#  'Untitled25.ipynb',
#  'Untitled26.ipynb',
#  'Untitled27.ipynb',
#  'Untitled28.ipynb',
#  'Untitled29.ipynb',
#  'Untitled3.ipynb',
#  'Untitled30.ipynb',
#  'Untitled31.ipynb',
#  'Untitled32.ipynb',
#  'Untitled33.ipynb',
#  'Untitled34.ipynb',
#  'Untitled35.ipynb',
#  'Untitled36.ipynb',
#  'Untitled37.ipynb',
#  'Untitled38.ipynb',
#  'Untitled39.ipynb',
#  'Untitled4.ipynb',
#  'Untitled40.ipynb',
#  'Untitled41.ipynb',
#  'Untitled42.ipynb',
#  'Untitled43.ipynb',
#  'Untitled44.ipynb',
#  'Untitled45.ipynb',
#  'Untitled46.ipynb',
#  'Untitled47.ipynb',
#  'Untitled48.ipynb',
#  'Untitled49.ipynb',
#  'Untitled5.ipynb',
#  'Untitled50.ipynb',
#  'Untitled51.ipynb',
#  'Untitled52.ipynb',
#  'Untitled53.ipynb',
#  'Untitled54.ipynb',
#  'Untitled55.ipynb',
#  'Untitled56.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  '__MACOSX']

# %% [markdown]
# <font color='teal'> **If you need to change your working directory by defining the path in the next cell make sure to uncomment the code before running the cell. If your path is fine, go on to the Load the data step.**</font>

# %%
#path=""
#os.chdir(path)

# %% [markdown]
# ### Load the data from the csv file
# Now you're ready to read your data into a pandas dataframe. In this exercise, this will complete the data collection step as all the data you need for your project are contained in this one csv file.
# *Double check your path is correct, and that between the `file` name and the `path`, you have the full location of your `updated_ski_data.csv`

# %% [markdown]
# <font color='teal'> **Load the data into a pandas dataframe and print the first five rows of the dataframe.**</font>

# %%
df= pd.read_csv('1589505302_05152020_updated_ski_data_-_updated_ski_data.csv')
df.head()
# Out:
#                   Name   Region    state  summit_elev  vertical_drop  \
# 0       Alyeska Resort   Alaska   Alaska         3939           2500
# 1  Eaglecrest Ski Area   Alaska   Alaska         2600           1540
# 2     Hilltop Ski Area   Alaska   Alaska         2090            294
# 3     Arizona Snowbowl  Arizona  Arizona        11500           2300
# 4  Sunrise Park Resort  Arizona  Arizona        11100           1800
#
#    base_elev  trams  fastEight  fastSixes  fastQuads  ...  LongestRun_mi  \
# 0        250      1        0.0          0          2  ...            1.0
# 1       1200      0        0.0          0          0  ...            2.0
# 2       1796      0        0.0          0          0  ...            1.0
# 3       9200      0        0.0          1          0  ...            2.0
# 4       9200      0        NaN          0          1  ...            1.2
#
#    SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# 0             1610.0           113.0             150.0       60.0
# 1              640.0            60.0              45.0       44.0
# 2               30.0            30.0             150.0       36.0
# 3              777.0           104.0             122.0       81.0
# 4              800.0            80.0             115.0       49.0
#
#    averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 0            669.0          65.0          85.0              150.0
# 1            350.0          47.0          53.0               90.0
# 2             69.0          30.0          34.0              152.0
# 3            260.0          89.0          89.0              122.0
# 4            250.0          74.0          78.0              104.0
#
#    NightSkiing_ac
# 0           550.0
# 1             NaN
# 2            30.0
# 3             NaN
# 4            80.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Data Organization

# %% [markdown]
# Data organization for this guided capstone involves creating a basic project folder structure. As you read in the Medium article introducing the data wrangling step, this step is often completed using Github or a module such as cookiecutter. Now that you have your data and your notebook pointing to your working project directory, let's start by printing the current file location. You'll then create a few subfolders to keep your project organized.

# %% [markdown]
# <font color='teal'> **Finish the statement below by assigning the path variable.**</font>

# %%
path = 'C:\\data_science'

# %%
print ("The current working directory is %s" % path)
# Out:
# The current working directory is C:\data_science

# %% [markdown]
# ### Create subfolders in your project directory

# %% [markdown]
# Now, create some subfolders inside your project folder.

# %% [markdown]
# <font color='teal'> **Create a subfolder called `data`.**</font>

# %% [markdown]
# <font color='teal'> **Create a folder for the data visualizations you will create in future steps called `figures`.**</font>

# %% [markdown]
# <font color='teal'> **Create a folder for the models you save, called `models`.**</font>

# %% [markdown]
# <font color='teal'> **Print the contents of your project folder to confirm you created the additional folders in your directory.**</font>

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01_first_notebook.ipynb',
#  '01_pandas_intro.ipynb',
#  '02_data_exploration.ipynb',
#  '1.Lab - Data structures in Python - Question.ipynb',
#  '1589505302_05152020_updated_ski_data_-_updated_ski_data.csv',
#  '2.Lab - Numpy-1.ipynb',
#  '3.Lab - Pandas-1.ipynb',
#  'applestore.csv',
#  'assignment3.png',
#  'Assignment3.py',
#  'assignment_3.png',
#  'Assignment_3.py',
#  'Assignment__3.py',
#  'bootcamp',
#  'cab.xlsx',
#  'cab_company.csv',
#  'cars1.csv',
#  'cars_df.png',
#  'Class10.xlsx',
#  'cos plot.png',
#  'data',
#  'Dcsv.csv',
#  'Dcsv1.csv',
#  'DS_Store',
#  'figures',
#  'file.xlsx',
#  'file1.ipynb',
#  'file2.ipynb',
#  'GitHub',
#  'googleplaystore.csv',
#  'GuidedCapstone_Step2HL (1).ipynb',
#  'image11.png',
#  'Insurance.csv',
#  'kaggle_clean.csv',
#  'kaggle_clean1.csv',
#  'Manoj.csv',
#  'models',
#  'mtcars.csv',
#  'multiple_choice_responses.csv',
#  'myarray.txt',
#  'New Microsoft Word Document.csv.docx',
#  'New Text Document.csv.txt',
#  'Numpy_and_its_functions.ipynb',
#  'output_companies1.csv',
#  'output_companies2.csv',
#  'output_companies3.txt',
#  'Pandas - Basics.ipynb',
#  'pandas-Consumer.xlsx',
#  'pandas-train.csv',
#  'PART 1, Tier 1 - Sourcing and Loading.ipynb',
#  'PART 2, Tier 1 - Cleaning, transforming and visualizing.ipynb',
#  'PART 3, Tier 1 - Modeling .ipynb',
#  'PART 3, Tier 2 - Modeling.ipynb',
#  'PART 3, Tier 3 - Modelling.ipynb',
#  'PART1, Tier 2 - Sourcing and Loading.ipynb',
#  'PART1, Tier 3 - Sourcing and Loading.ipynb',
#  'PART2, Tier 2 - Cleaning, transforming and visualizing .ipynb',
#  'SagarikaGhosal_Assignment3.ipynb',
#  'SagarikaGhosal_assignment3.png',
#  'SagarikaGhosal_Assignment3.py',
#  'saved_archive.npz',
#  'saved_array.npy',
#  'Tableau',
#  'takenmind.ipynb',
#  'takenmind.py',
#  'titanic.csv',
#  'TMInternship.ipynb',
#  'TMInternship.py',
#  'Unit 4 Challenge - Tier 3.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled14.ipynb',
#  'Untitled15.ipynb',
#  'Untitled16.ipynb',
#  'Untitled17.ipynb',
#  'Untitled18.ipynb',
#  'Untitled19.ipynb',
#  'Untitled2.ipynb',
#  'Untitled20.ipynb',
#  'Untitled21.ipynb',
#  'Untitled22.ipynb',
#  'Untitled23.ipynb',
#  'Untitled24.ipynb',
#  'Untitled25.ipynb',
#  'Untitled26.ipynb',
#  'Untitled27.ipynb',
#  'Untitled28.ipynb',
#  'Untitled29.ipynb',
#  'Untitled3.ipynb',
#  'Untitled30.ipynb',
#  'Untitled31.ipynb',
#  'Untitled32.ipynb',
#  'Untitled33.ipynb',
#  'Untitled34.ipynb',
#  'Untitled35.ipynb',
#  'Untitled36.ipynb',
#  'Untitled37.ipynb',
#  'Untitled38.ipynb',
#  'Untitled39.ipynb',
#  'Untitled4.ipynb',
#  'Untitled40.ipynb',
#  'Untitled41.ipynb',
#  'Untitled42.ipynb',
#  'Untitled43.ipynb',
#  'Untitled44.ipynb',
#  'Untitled45.ipynb',
#  'Untitled46.ipynb',
#  'Untitled47.ipynb',
#  'Untitled48.ipynb',
#  'Untitled49.ipynb',
#  'Untitled5.ipynb',
#  'Untitled50.ipynb',
#  'Untitled51.ipynb',
#  'Untitled52.ipynb',
#  'Untitled53.ipynb',
#  'Untitled54.ipynb',
#  'Untitled55.ipynb',
#  'Untitled56.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  '__MACOSX']

# %% [markdown]
# ## Data Definition
# In this step, you'll review column names, data types, and null values.

# %% [markdown]
# ### Column Names
# <font color='teal'> **Print the columns names of the entire dataframe**</font>

# %%
df.columns
# Out:
# Index(['Name', 'Region', 'state', 'summit_elev', 'vertical_drop', 'base_elev',
#        'trams', 'fastEight', 'fastSixes', 'fastQuads', 'quad', 'triple',
#        'double', 'surface', 'total_chairs', 'Runs', 'TerrainParks',
#        'LongestRun_mi', 'SkiableTerrain_ac', 'Snow Making_ac',
#        'daysOpenLastYear', 'yearsOpen', 'averageSnowfall', 'AdultWeekday',
#        'AdultWeekend', 'projectedDaysOpen', 'NightSkiing_ac'],
#       dtype='object')

# %% [markdown]
# ### Data Types
# Review which columns are integer, float, categorical, or dates. Make sure the data type is loaded properly in the dataframe.

# %% [markdown]
# <font color='teal'> **Using the `df.dtypes` function, print the variable names and associated datatypes.**</font>

# %%
df.dtypes
# Out:
# Name                  object
# Region                object
# state                 object
# summit_elev            int64
# vertical_drop          int64
# base_elev              int64
# trams                  int64
# fastEight            float64
# fastSixes              int64
# fastQuads              int64
# quad                   int64
# triple                 int64
# double                 int64
# surface                int64
# total_chairs           int64
# Runs                 float64
# TerrainParks         float64
# LongestRun_mi        float64
# SkiableTerrain_ac    float64
# Snow Making_ac       float64
# daysOpenLastYear     float64
# yearsOpen            float64
# averageSnowfall      float64
# AdultWeekday         float64
# AdultWeekend         float64
# projectedDaysOpen    float64
# NightSkiing_ac       float64
# dtype: object

# %% [markdown]
# <font color='teal'> **The `df.info()` function also prints the count of non-null values per column. Use this function to review the column names, null value counts and data types of your data frame.**</font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               330 non-null    object
#  1   Region             330 non-null    object
#  2   state              330 non-null    object
#  3   summit_elev        330 non-null    int64
#  4   vertical_drop      330 non-null    int64
#  5   base_elev          330 non-null    int64
#  6   trams              330 non-null    int64
#  7   fastEight          164 non-null    float64
#  8   fastSixes          330 non-null    int64
#  9   fastQuads          330 non-null    int64
#  10  quad               330 non-null    int64
#  11  triple             330 non-null    int64
#  12  double             330 non-null    int64
#  13  surface            330 non-null    int64
#  14  total_chairs       330 non-null    int64
#  15  Runs               326 non-null    float64
#  16  TerrainParks       279 non-null    float64
#  17  LongestRun_mi      325 non-null    float64
#  18  SkiableTerrain_ac  327 non-null    float64
#  19  Snow Making_ac     284 non-null    float64
#  20  daysOpenLastYear   279 non-null    float64
#  21  yearsOpen          329 non-null    float64
#  22  averageSnowfall    316 non-null    float64
#  23  AdultWeekday       276 non-null    float64
#  24  AdultWeekend       279 non-null    float64
#  25  projectedDaysOpen  283 non-null    float64
#  26  NightSkiing_ac     187 non-null    float64
# dtypes: float64(13), int64(11), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# Some of these column names are easy to understand but others are not as clear. You have a metadata file with information about each column to help you understand what the column names refer to. Let's review the metadata table below for more information about each column.

# %% [markdown]
# Descriptions of Columns

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There are some null or missing values you'll need to mitgate in a later step. However, let's look at the counts of unique values or codes per column first.

# %% [markdown]
# ### Count of unique values or codes
# <font color='teal'> **Print the count of unique values for every column, regardless of data type.**</font>

# %%
[(df[x].nunique()) for x in df.columns]
# Out:
# [329,
#  38,
#  35,
#  266,
#  193,
#  244,
#  5,
#  2,
#  7,
#  14,
#  7,
#  9,
#  10,
#  12,
#  31,
#  110,
#  11,
#  42,
#  193,
#  143,
#  111,
#  72,
#  107,
#  83,
#  81,
#  90,
#  78]

# %% [markdown]
# <font color='teal'> **Print the percent of unique values per column. Use the `df.nunique` and the size of the dataframe to calculate the percentages.**</font>

# %%
[(df[x].nunique()/330*100) for x in df.columns]
# Out:
# [99.69696969696969,
#  11.515151515151516,
#  10.606060606060606,
#  80.60606060606061,
#  58.484848484848484,
#  73.93939393939394,
#  1.5151515151515151,
#  0.6060606060606061,
#  2.1212121212121215,
#  4.242424242424243,
#  2.1212121212121215,
#  2.727272727272727,
#  3.0303030303030303,
#  3.6363636363636362,
#  9.393939393939393,
#  33.33333333333333,
#  3.3333333333333335,
#  12.727272727272727,
#  58.484848484848484,
#  43.333333333333336,
#  33.63636363636363,
#  21.818181818181817,
#  32.42424242424242,
#  25.151515151515152,
#  24.545454545454547,
#  27.27272727272727,
#  23.636363636363637]

# %% [markdown]
# When working with categorical columns, it's really helpful to know what the unique codes are. <font color='teal'> **For example, if you look at the `Region` or `state` column, youcan print out the different states in the dataframe.**</font>
#
# Hint: you can use the `value_counts()` method for this.

# %%
df['Region'].value_counts()
# Out:
# New York               33
# Michigan               29
# Colorado               22
# Sierra Nevada          22
# Pennsylvania           19
# Wisconsin              16
# New Hampshire          16
# Vermont                15
# Minnesota              14
# Idaho                  12
# Montana                12
# Massachusetts          11
# Washington             10
# New Mexico              9
# Maine                   9
# Wyoming                 8
# Utah                    7
# North Carolina          6
# Salt Lake City          6
# Oregon                  6
# Ohio                    5
# Connecticut             5
# Virginia                4
# Mt. Hood                4
# Illinois                4
# West Virginia           4
# Alaska                  3
# Iowa                    3
# Missouri                2
# New Jersey              2
# Indiana                 2
# Nevada                  2
# Arizona                 2
# South Dakota            2
# Tennessee               1
# Rhode Island            1
# Maryland                1
# Northern California     1
# Name: Region, dtype: int64

# %% [markdown]
# ### Range of values per column
#
# <font color='teal'>**Print the range of values using the aggregate function.**</font>
#
# Hint: you can do this in a variety of ways, but one way is using the `agg()` dataframe method. You can pass this the `[min, max]` parameter and then call `.T` on the result to transpose it.

# %%
df.agg([min,max]).T
# Out:
#                                 min                            max
# Name               49 Degrees North  Yosemite Ski & Snowboard Area
# Region                       Alaska                        Wyoming
# state                        Alaska                        Wyoming
# summit_elev                     315                          13487
# vertical_drop                    60                           4425
# base_elev                        70                          10800
# trams                             0                              4
# fastEight                         0                              1
# fastSixes                         0                              6
# fastQuads                         0                             15
# quad                              0                              8
# triple                            0                              8
# double                            0                             14
# surface                           0                             15
# total_chairs                      0                             41
# Runs                              3                            341
# TerrainParks                      1                             14
# LongestRun_mi                     0                              6
# SkiableTerrain_ac                 8                          26819
# Snow Making_ac                    2                           3379
# daysOpenLastYear                  3                            305
# yearsOpen                         6                           2019
# averageSnowfall                  18                            669
# AdultWeekday                     15                            179
# AdultWeekend                     17                            179
# projectedDaysOpen                30                            305
# NightSkiing_ac                    2                            650

# %% [markdown]
# <font color='teal'> **Review the numeric dataset's summary statistics.**</font>

# %%
df.describe()
# Out:
#         summit_elev  vertical_drop     base_elev       trams   fastEight  \
# count    330.000000     330.000000    330.000000  330.000000  164.000000
# mean    4591.818182    1215.427273   3374.000000    0.172727    0.006098
# std     3735.535934     947.864557   3117.121621    0.559946    0.078087
# min      315.000000      60.000000     70.000000    0.000000    0.000000
# 25%     1403.750000     461.250000    869.000000    0.000000    0.000000
# 50%     3127.500000     964.500000   1561.500000    0.000000    0.000000
# 75%     7806.000000    1800.000000   6325.250000    0.000000    0.000000
# max    13487.000000    4425.000000  10800.000000    4.000000    1.000000
#
#         fastSixes   fastQuads        quad     triple      double  ...  \
# count  330.000000  330.000000  330.000000  330.00000  330.000000  ...
# mean     0.184848    1.018182    0.933333    1.50000    1.833333  ...
# std      0.651685    2.198294    1.312245    1.61913    1.815028  ...
# min      0.000000    0.000000    0.000000    0.00000    0.000000  ...
# 25%      0.000000    0.000000    0.000000    0.00000    1.000000  ...
# 50%      0.000000    0.000000    0.000000    1.00000    1.000000  ...
# 75%      0.000000    1.000000    1.000000    2.00000    3.000000  ...
# max      6.000000   15.000000    8.000000    8.00000   14.000000  ...
#
#        LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  \
# count     325.000000         327.000000      284.000000        279.000000
# mean        1.433231         739.801223      174.873239        115.103943
# std         1.156171        1816.167441      261.336125         35.063251
# min         0.000000           8.000000        2.000000          3.000000
# 25%         0.500000          85.000000       50.000000         97.000000
# 50%         1.000000         200.000000      100.000000        114.000000
# 75%         2.000000         690.000000      200.500000        135.000000
# max         6.000000       26819.000000     3379.000000        305.000000
#
#          yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# count   329.000000       316.000000    276.000000    279.000000
# mean     63.656535       185.316456     57.916957     64.166810
# std     109.429928       136.356842     26.140126     24.554584
# min       6.000000        18.000000     15.000000     17.000000
# 25%      50.000000        69.000000     40.000000     47.000000
# 50%      58.000000       150.000000     50.000000     60.000000
# 75%      69.000000       300.000000     71.000000     77.500000
# max    2019.000000       669.000000    179.000000    179.000000
#
#        projectedDaysOpen  NightSkiing_ac
# count         283.000000      187.000000
# mean          120.053004      100.395722
# std            31.045963      105.169620
# min            30.000000        2.000000
# 25%           100.000000       40.000000
# 50%           120.000000       72.000000
# 75%           139.500000      114.000000
# max           305.000000      650.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Handle the missing and NA values
# Run the code below to print out the percent of each feature that is missing. You can see from the result of the code that there are 13 columns out of 27 missing data. Most of these are missing less than 10% of the data. You may need to adapt the code if your dataframe is named something other than df.
#
#
# *   Consider the columns individually
# *   Identify the appropriate fill method for each column

# %%
nas=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)/len(df),columns = ['percent'])
pos = nas['percent'] > 0
nas[pos]
# Out:
#                     percent
# fastEight          0.503030
# NightSkiing_ac     0.433333
# AdultWeekday       0.163636
# AdultWeekend       0.154545
# daysOpenLastYear   0.154545
# TerrainParks       0.154545
# projectedDaysOpen  0.142424
# Snow Making_ac     0.139394
# averageSnowfall    0.042424
# LongestRun_mi      0.015152
# Runs               0.012121
# SkiableTerrain_ac  0.009091
# yearsOpen          0.003030

# %% [markdown]
# Let's review each of these columns in the data.
#
#
# *   fastEight is the number of fast eight-person ski lifts at each of the resorts. In addition, you have the counts of all the other types of chairs at each resort and the total number of chairs as well. You can simply subtract the number of fastEight lifts from the total to determine if any of the missing values can be backfilled or if they should be equal to zero. Follow the next step below and see for yourself how to review and backfill these missing values. These columns contain all the resort lift counts by type.
#
#
# * trams
# * fastEight
# * fastSixes
# * fastQuads
# * quad
# * triple
# * double
# * surface
# * total_chairs <- the sum of these columns for each row.

# %% [markdown]
# <font color='teal'> **In order to determine an appropriate fill value for the fastEigth column, you need to calculate the difference between the sum of all the chairlift columns and the `total_chairs` column.**</font>

# %%
sum([df[x].sum() for x in ['fastEight', 'fastSixes', 'fastQuads', 'quad', 'triple', 'double', 'surface','trams']])
# Out:
# 2728.0

# %%
df['total_chairs'].agg(sum)
# Out:
# 2728

# %% [markdown]
# As you can see from running the above cell, there are no fastEight lift values missing because the difference between the sum of all the lift columns and the 'total_chairs' column is zero for every row in the dataframe. This confirms that you can therefore replace the missing values for the fastEight rows with zeros.

# %% [markdown]
# <font color='teal'> **In the cell below, replace Nan's in 'fastEight' with zero.**</font>
#
# Hint: you could use the `fillna()` method here.

# %%
df['fastEight'].fillna(0, inplace=True)

# %%
df['NightSkiing_ac'].fillna(0, inplace=True)

# %% [markdown]
# Consider the next column with missing values, 'NightSkiing_ac'. This column represents the number of acres of night skiing availble at this resort. Not all resorts have night skiing because it requires stadium lights and is not that popular with skiers and snowboarders. Given that information, it is also safe to assume that if there are missing values in this column, it is due to there not being any night skiing acres available at that resort so you can fill missing values with zeros safely.

# %% [markdown]
# Next, let's consider the ticket price columns 'AdultWeekday' & 'AdultWeekend'. You know that there has to be a price for these that happens to be missing so, in this case, you cannot fill the missing values with zeros. Instead, you have a few options about what value you can use to fill the missing rows. You can simply take the mean of the column in consideration or you could backfill or forwardfill from the resort in the row before or after your missing value. Backfill and forward fill would be more reasonable in a situation where the data are in a particular order where the rows near each other are similar to each other in the price column. You could also build an imputation model to use a model to predict the value based on the data values in adjacent columns as well as adjacent rows.

# %% [markdown]
# <font color='teal'> **Run the cell below to replace Nan's in 'AdultWeekday' with the mean value.**</font>

# %%
df['AdultWeekday'].fillna((df['AdultWeekday'].mean()), inplace=True)

# %% [markdown]
# <font color='teal'> **Use what you know about the remaining columns missing data and decide whether to fill with a zero or to fill with a mean.**</font>

# %%
df['AdultWeekend'].fillna((df['AdultWeekend'].mean()), inplace=True)

# %%
df[np.isnan(df['daysOpenLastYear'])]
# Out:
#                              Name          Region           state  \
# 9                     Dodge Ridge   Sierra Nevada      California
# 12                  June Mountain   Sierra Nevada      California
# 21                    Snow Summit   Sierra Nevada      California
# 48                Mohawk Mountain     Connecticut     Connecticut
# 55          Kelly Canyon Ski Area           Idaho           Idaho
# 64                Tamarack Resort           Idaho           Idaho
# 68                   Villa Olivia        Illinois        Illinois
# 71          Mt. Crescent Ski Area            Iowa            Iowa
# 73               Sundown Mountain            Iowa            Iowa
# 78                  Mt. Jefferson           Maine           Maine
# 85             Blandford Ski Area   Massachusetts   Massachusetts
# 86            Blue Hills Ski Area   Massachusetts   Massachusetts
# 87              Bousquet Ski Area   Massachusetts   Massachusetts
# 88              Bradford Ski Area   Massachusetts   Massachusetts
# 94    Wachusett Mountain Ski Area   Massachusetts   Massachusetts
# 95         Alpine Valley Ski Area        Michigan        Michigan
# 96                 Apple Mountain        Michigan        Michigan
# 111                   Mount Holly        Michigan        Michigan
# 112    Mulligan's Hollow Ski Bowl        Michigan        Michigan
# 115          Pine Knob Ski Resort        Michigan        Michigan
# 119  Snow Snake Mountain Ski Area        Michigan        Michigan
# 138        Hidden Valley Ski Area        Missouri        Missouri
# 141   Blacktail Mountain Ski Area         Montana         Montana
# 146             Maverick Mountain         Montana         Montana
# 147              Montana Snowbowl         Montana         Montana
# 168        Ragged Mountain Resort   New Hampshire   New Hampshire
# 184          Brantling Ski Slopes        New York        New York
# 186     Buffalo Ski Club Ski Area        New York        New York
# 188             Dry Hill Ski Area        New York        New York
# 194          Hunt Hollow Ski Club        New York        New York
# 197                  Labrador Mt.        New York        New York
# 198               Maple Ski Ridge        New York        New York
# 201                  Oak Mountain        New York        New York
# 204       Royal Mountain Ski Area        New York        New York
# 210           Toggenburg Mountain        New York        New York
# 211                 West Mountain        New York        New York
# 215         Woods Valley Ski Area        New York        New York
# 221         Wolf Ridge Ski Resort  North Carolina  North Carolina
# 243                    Eagle Rock    Pennsylvania    Pennsylvania
# 244       Elk Mountain Ski Resort    Pennsylvania    Pennsylvania
# 248      Roundtop Mountain Resort    Pennsylvania    Pennsylvania
# 251                   Ski Sawmill    Pennsylvania    Pennsylvania
# 264            Deer Valley Resort  Salt Lake City            Utah
# 265                   Eagle Point            Utah            Utah
# 274              Bromley Mountain         Vermont         Vermont
# 282                 Pico Mountain         Vermont         Vermont
# 295              Crystal Mountain      Washington      Washington
# 302          Canaan Valley Resort   West Virginia   West Virginia
# 314            Little Switzerland       Wisconsin       Wisconsin
# 325          Meadowlark Ski Lodge         Wyoming         Wyoming
# 329           White Pine Ski Area         Wyoming         Wyoming
#
#      summit_elev  vertical_drop  base_elev  trams  fastEight  fastSixes  \
# 9           8200           1600       6600      0        0.0          0
# 12         10090           2590       7545      0        0.0          0
# 21          8200           1200       7000      0        0.0          0
# 48          1600            650        950      0        0.0          0
# 55          6600           1000       5600      0        0.0          0
# 64          7700           2800       4900      0        0.0          0
# 68           500            180        320      0        0.0          0
# 71          1500            300       1200      0        0.0          0
# 73          1059            475        584      0        0.0          0
# 78           753            432        351      0        0.0          0
# 85          1685            465       1035      0        0.0          0
# 86           635            309        326      0        0.0          0
# 87          1875            750       1125      0        0.0          0
# 88          1548            248       1300      0        0.0          0
# 94          2006           1000       1006      0        0.0          0
# 95           500            240        126      0        0.0          0
# 96           820            220        600      0        0.0          0
# 111         1105            350        755      0        0.0          0
# 112          700            130        570      0        0.0          0
# 115         1308            300       1009      0        0.0          0
# 119         1230            210       1020      0        0.0          0
# 138         2566            310       2316      0        0.0          0
# 141         6676           1440       5236      0        0.0          0
# 146         8520           2020       6500      0        0.0          0
# 147         7600           2600       5000      0        0.0          0
# 168         2250           1250       1000      0        0.0          1
# 184          850            250        600      0        0.0          0
# 186         3429            500       2025      0        0.0          0
# 188          950            300        650      0        0.0          0
# 194         2030            825       1000      0        0.0          0
# 197         1825            700       1125      0        0.0          0
# 198         1200            450        750      0        0.0          0
# 201         2400            650       1750      0        0.0          0
# 204         1800            550       1250      0        0.0          0
# 210         2000            700       1300      0        0.0          0
# 211         1470           1010        460      0        0.0          0
# 215         1400            500        900      0        0.0          0
# 221         4700            720       4000      0        0.0          0
# 243         1810            550       1260      0        0.0          0
# 244         2693           1000       1693      0        0.0          0
# 248         1400            600        800      0        0.0          0
# 251         2215            515       1700      0        0.0          0
# 264         9570           3000       6570      1        0.0          0
# 265        10600           1500       9100      0        0.0          0
# 274         3284           1334       1950      0        0.0          0
# 282         3967           1967       2000      0        0.0          0
# 295         7012           3100       4400      1        0.0          2
# 302         4280            850       3430      0        0.0          0
# 314         1269            200       1069      0        0.0          0
# 325         9500           1000       8500      0        0.0          0
# 329         9500           1100       8400      0        0.0          0
#
#      fastQuads  ...  LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  \
# 9            0  ...            2.0              862.0             NaN
# 12           2  ...            2.0             1500.0             NaN
# 21           2  ...            1.2              240.0           240.0
# 48           0  ...            1.5              107.0           100.0
# 55           0  ...            1.3              740.0             NaN
# 64           2  ...            1.5             1020.0           200.0
# 68           0  ...            0.1               15.0            15.0
# 71           0  ...            0.2               50.0            50.0
# 73           0  ...            0.6               55.0            55.0
# 78           0  ...            0.3               12.0             NaN
# 85           0  ...            0.5              132.0            70.0
# 86           0  ...            NaN               60.0            60.0
# 87           0  ...            1.0              200.0            98.0
# 88           0  ...            0.3               48.0            48.0
# 94           3  ...            1.5              112.0           112.0
# 95           0  ...            0.2              100.0           100.0
# 96           0  ...            NaN               80.0            42.0
# 111          1  ...            0.1              100.0           100.0
# 112          0  ...            0.2               10.0            10.0
# 115          0  ...            1.0               80.0            80.0
# 119          0  ...            0.0               40.0            40.0
# 138          0  ...            0.1               30.0            30.0
# 141          0  ...            0.7             1000.0             NaN
# 146          0  ...            1.3              255.0             NaN
# 147          0  ...            1.2              950.0            20.0
# 168          1  ...            0.7              250.0           200.0
# 184          0  ...            0.1               20.0            16.0
# 186          0  ...            NaN              225.0           150.0
# 188          0  ...            0.2               35.0            26.0
# 194          0  ...            1.0              400.0           400.0
# 197          0  ...            1.0              250.0           237.0
# 198          0  ...            0.3               25.0            25.0
# 201          0  ...            1.2               46.0            18.0
# 204          0  ...            0.3               35.0            28.0
# 210          0  ...            0.4               85.0             NaN
# 211          0  ...            0.6              124.0           105.0
# 215          0  ...            0.3               25.0            16.0
# 221          0  ...            0.6               65.0            65.0
# 243          0  ...            1.0                NaN             NaN
# 244          0  ...            0.7              180.0           146.0
# 248          0  ...            0.4              103.0           103.0
# 251          0  ...            0.1               15.0            13.0
# 264         13  ...            2.8             2026.0           660.0
# 265          0  ...            0.9              650.0             NaN
# 274          1  ...            2.5              178.0           153.0
# 282          2  ...            4.0              260.0           156.0
# 295          2  ...            2.5             2600.0            10.0
# 302          0  ...            1.2               95.0            75.0
# 314          0  ...            1.0               50.0            50.0
# 325          0  ...            1.5              300.0             NaN
# 329          0  ...            0.4              370.0             NaN
#
#      daysOpenLastYear  yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# 9                 NaN       69.0            350.0     78.000000      78.00000
# 12                NaN       58.0            250.0     57.916957      64.16681
# 21                NaN       67.0            100.0     57.916957      64.16681
# 48                NaN       72.0             92.0     30.000000      65.00000
# 55                NaN       62.0            200.0     57.916957      42.00000
# 64                NaN       15.0            300.0     71.000000      71.00000
# 68                NaN       53.0             25.0     40.000000      40.00000
# 71                NaN       58.0             30.0     29.000000      39.00000
# 73                NaN       46.0             45.0     38.000000      46.00000
# 78                NaN       19.0              NaN     57.916957      64.16681
# 85                NaN       83.0             50.0     20.000000      45.00000
# 86                NaN       19.0              NaN     40.000000      45.00000
# 87                NaN       19.0             83.0     25.000000      49.00000
# 88                NaN       71.0              NaN     37.000000      55.00000
# 94                NaN       57.0            100.0     65.000000      71.00000
# 95                NaN       57.0             20.0     39.000000      47.00000
# 96                NaN       58.0             52.0     35.000000      35.00000
# 111               NaN       63.0             42.0     37.000000      45.00000
# 112               NaN       19.0             60.0     15.000000      20.00000
# 115               NaN     2019.0              NaN     49.000000      57.00000
# 119               NaN       72.0              NaN     30.000000      35.00000
# 138               NaN       37.0             26.0     49.000000      49.00000
# 141               NaN       21.0            250.0     42.000000      42.00000
# 146               NaN       83.0            160.0     39.000000      39.00000
# 147               NaN       58.0            300.0     50.000000      50.00000
# 168               NaN       54.0            100.0     74.000000      84.00000
# 184               NaN       19.0            110.0     32.000000      32.00000
# 186               NaN       12.0              NaN     35.000000      50.00000
# 188               NaN       55.0            125.0     57.916957      35.00000
# 194               NaN       52.0            130.0     48.000000      58.00000
# 197               NaN       62.0            125.0     59.000000      59.00000
# 198               NaN       57.0              NaN     26.000000      38.00000
# 201               NaN       71.0            120.0     40.000000      40.00000
# 204               NaN       63.0             90.0     45.000000      45.00000
# 210               NaN       66.0            130.0     55.000000      55.00000
# 211               NaN       58.0             80.0     49.000000      59.00000
# 215               NaN       55.0            180.0     31.000000      39.00000
# 221               NaN       49.0             65.0     42.000000      65.00000
# 243               NaN       47.0              NaN     57.916957      64.16681
# 244               NaN       60.0             60.0     55.000000      69.00000
# 248               NaN       55.0             30.0     63.000000      73.00000
# 251               NaN       50.0             24.0     30.000000      44.00000
# 264               NaN       39.0            300.0    169.000000     169.00000
# 265               NaN        9.0            400.0     45.000000      60.00000
# 274               NaN       83.0            168.0     87.000000      91.00000
# 282               NaN       82.0            250.0     81.000000      81.00000
# 295               NaN       57.0            486.0     99.000000      99.00000
# 302               NaN       48.0            160.0     52.000000      68.00000
# 314               NaN        NaN              NaN     33.000000      41.00000
# 325               NaN        9.0              NaN     57.916957      64.16681
# 329               NaN       81.0            150.0     57.916957      49.00000
#
#      projectedDaysOpen  NightSkiing_ac
# 9                140.0             0.0
# 12               128.0             0.0
# 21               130.0           150.0
# 48               110.0            64.0
# 55                 NaN             0.0
# 64               150.0             0.0
# 68                70.0            15.0
# 71                 NaN            50.0
# 73                 NaN            55.0
# 78                 NaN             0.0
# 85                 NaN            70.0
# 86                 NaN             0.0
# 87                 NaN           100.0
# 88                 NaN             0.0
# 94               120.0           104.0
# 95                 NaN           100.0
# 96                 NaN            80.0
# 111              102.0           100.0
# 112                NaN            10.0
# 115                NaN             0.0
# 119                NaN            40.0
# 138                NaN            17.0
# 141                NaN             0.0
# 146                NaN             0.0
# 147                NaN            10.0
# 168              140.0             0.0
# 184                NaN             0.0
# 186                NaN           100.0
# 188                NaN            26.0
# 194               75.0           400.0
# 197              100.0           180.0
# 198                NaN            20.0
# 201                NaN            12.0
# 204                NaN             0.0
# 210              122.0            73.0
# 211              120.0           105.0
# 215                NaN            15.0
# 221              100.0            60.0
# 243               40.0             0.0
# 244              100.0            90.0
# 248                NaN           100.0
# 251               90.0            15.0
# 264                NaN             0.0
# 265              109.0             0.0
# 274              152.0             0.0
# 282                NaN             0.0
# 295                NaN             0.0
# 302               93.0             0.0
# 314                NaN            50.0
# 325                NaN             0.0
# 329                NaN             0.0
#
# [51 rows x 27 columns]

# %%
df['daysOpenLastYear'].hist()
#Since the distribution is almost, using mean to fill na values

# %%
df['daysOpenLastYear'].fillna((df['daysOpenLastYear'].mean()), inplace=True)

# %%
df['TerrainParks'].hist()
#Since distribution is skewed-right, using median to fill na values

# %%
df['TerrainParks'].fillna((df['TerrainParks'].median()), inplace=True)

# %%
df['projectedDaysOpen'].hist()
#Since this an almost normalized distribution, using mean here

# %%
df['projectedDaysOpen'].fillna((df['projectedDaysOpen'].mean()),inplace=True)

# %%
df['Snow Making_ac'].hist()
#Since distribution is slightly skewed-right, using median

# %%
df['Snow Making_ac'].fillna((df['Snow Making_ac'].median()),inplace=True)

# %%
df['averageSnowfall'].hist()
#Distribution here is skewed-right, using median

# %%
df['averageSnowfall'].fillna((df['averageSnowfall'].median()),inplace=True)

# %%
df['LongestRun_mi'].hist()
#Distribution is right skewed, using median

# %%
df['LongestRun_mi'].fillna((df['LongestRun_mi'].median()),inplace=True)

# %%
df['Runs'].hist()
#Distribution is skewed right, using median

# %%
df['Runs'].fillna((df['Runs'].median()),inplace=True)

# %%
df['SkiableTerrain_ac'].hist(bins=50)
#Distribution is skewed-right, using median

# %%
df['SkiableTerrain_ac'].fillna((df['SkiableTerrain_ac'].median()),inplace=True)

# %%
df['yearsOpen'].hist(bins=100)
#Distribution is slightly skewed, using median

# %%
df['yearsOpen'].fillna((df['yearsOpen'].median()),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               330 non-null    object
#  1   Region             330 non-null    object
#  2   state              330 non-null    object
#  3   summit_elev        330 non-null    int64
#  4   vertical_drop      330 non-null    int64
#  5   base_elev          330 non-null    int64
#  6   trams              330 non-null    int64
#  7   fastEight          330 non-null    float64
#  8   fastSixes          330 non-null    int64
#  9   fastQuads          330 non-null    int64
#  10  quad               330 non-null    int64
#  11  triple             330 non-null    int64
#  12  double             330 non-null    int64
#  13  surface            330 non-null    int64
#  14  total_chairs       330 non-null    int64
#  15  Runs               330 non-null    float64
#  16  TerrainParks       330 non-null    float64
#  17  LongestRun_mi      330 non-null    float64
#  18  SkiableTerrain_ac  330 non-null    float64
#  19  Snow Making_ac     330 non-null    float64
#  20  daysOpenLastYear   330 non-null    float64
#  21  yearsOpen          330 non-null    float64
#  22  averageSnowfall    330 non-null    float64
#  23  AdultWeekday       330 non-null    float64
#  24  AdultWeekend       330 non-null    float64
#  25  projectedDaysOpen  330 non-null    float64
#  26  NightSkiing_ac     330 non-null    float64
# dtypes: float64(13), int64(11), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# ### Look for duplicate rows
# Run the code below to print out the duplicated rows.You can see there are no duplicate rows, so in this particular case there is nothing else to do related to duplicate rows. You will review duplicate or synonymous columns in Step 3 of the Guided Capstone.

# %%
duplicateRowsDF = df[df.duplicated()]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [Name, Region, state, summit_elev, vertical_drop, base_elev, trams, fastEight, fastSixes, fastQuads, quad, triple, double, surface, total_chairs, Runs, TerrainParks, LongestRun_mi, SkiableTerrain_ac, Snow Making_ac, daysOpenLastYear, yearsOpen, averageSnowfall, AdultWeekday, AdultWeekend, projectedDaysOpen, NightSkiing_ac]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# ## Export data to a new csv file
# In order to bring the changes you made here into the next notebook, you need to write out the updated data frame to a new csv file.

# %% [markdown]
# <font color='teal'> **Export the processed dataframe as a csv file to the data folder you created earlier. Name this new csv file `step2_output.csv`.**</font>
#
# Hint: you can use the `to_csv()` dataframe method here.

# %%
df.to_csv('step2_output.csv')

# %% [markdown]
# The data transformations created in this step of the DSM are all generally steps to be applied to any data science project. However, the decisions we made about how to handle the missing and NA data are specific to the problem at hand. In the next step of the DSM and the next Guided Capstone Notebook, you'll see how all these steps prepare the data for exploratory data analysis.
